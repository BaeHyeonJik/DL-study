# %% [markdown]
# ## 12. Reading and Preprocessing Images
#
# - 이미지의 기본 형식: `H(Height) × W(Weight) × C(Channel)`
#
#     ⇒ 이미지의 channel은 RGB: 3
#
# - 처리 과정(CNN 하기 전 조치):
#     1. float32로 변환
#     2. 텐서화 (Tensor로 변환)
#     3. 정규화(Normalization)
#     4. 텐서 차원 변경: `C × H * W`
#     5. 배치 처리: `B(Batch) * C × H * W`

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
import torch
from torchvision import datasets, transforms

# 이미지 변환
transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# CIFAR-10은 10개의 클래스에 걸쳐 총 60,000개의 32x32 컬러 이미지로 구성된 데이터셋
train_dataset = datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transforms
)
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=128,
    shuffle=True,
)

val_dataset = datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transforms
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=128,
    shuffle=False,
)

print("Train dataset size:", len(train_dataset))
print("Validation dataset size:", len(val_dataset))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train dataset size: 50000
# Validation dataset size: 10000

# %%
import numpy as np

train_dataset_img, train_dataset_label = train_dataset[3]
train_loader_img, train_loader_label = next(iter(train_loader))

train_dataset_np = np.array(train_dataset_img)
train_loader_np = np.array(train_loader_img)

print(f'train_dataset_img shape: {train_dataset_img.shape}')
print(f'train_loader_img shape: {train_loader_img.shape}')
# Out:
# train_dataset_img shape: torch.Size([3, 32, 32])
# train_loader_img shape: torch.Size([128, 3, 32, 32])

# %%
import torch.nn as nn

class SimpleCNN(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super().__init__()
    self.seq_model = nn.Sequential(
      nn.Linear(input_size, hidden_size),
      nn.ReLU(),
      nn.Linear(hidden_size, hidden_size),
      nn.ReLU(),
      nn.Linear(hidden_size, hidden_size),
      nn.ReLU(),
      nn.Dropout(),
      nn.Linear(hidden_size, hidden_size),
      nn.ReLU(),
      nn.Dropout(),
      nn.Linear(hidden_size, output_size)
    )

  def forward(self, x):
    x = x.view(x.size(0), -1)
    return self.seq_model(x)

# %%
mynet = SimpleCNN(input_size=32*32*3, hidden_size=128, output_size=10)
mynet = mynet.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mynet.parameters(), lr=0.001)

for epoch in range(100):
  mynet.train()
  for batch_idx, (data, label) in enumerate(train_loader):
    data, label = data.to(device), label.to(device)
    optimizer.zero_grad()
    output = mynet(data)
    train_loss = loss_fn(output, label)
    train_loss.backward()
    optimizer.step()

  mynet.eval()
  val_loss = 0
  correct = 0
  with torch.no_grad():
    for data, label in val_loader:
      data, label = data.to(device), label.to(device)
      output = mynet(data)
      val_loss += loss_fn(output, label).item()
      pred = output.argmax(dim=1, keepdim=True)
      correct += pred.eq(label.view_as(pred)).sum().item()
  
  val_loss /= len(val_loader.dataset)
  accuracy = 100. * correct / len(val_loader.dataset)

  print(f'Epoch {epoch+1}, Loss: {train_loss.item():.4f}, Val Loss: {val_loss:.4f}, Accuracy: {accuracy:.2f}%')
# Out:
# Epoch 1, Loss: 1.5829, Val Loss: 0.0127, Accuracy: 43.49%
# Epoch 2, Loss: 1.6539, Val Loss: 0.0119, Accuracy: 46.78%
# Epoch 3, Loss: 1.4673, Val Loss: 0.0114, Accuracy: 49.13%
# Epoch 4, Loss: 1.3113, Val Loss: 0.0111, Accuracy: 50.79%
# Epoch 5, Loss: 1.4199, Val Loss: 0.0110, Accuracy: 51.55%
# Epoch 6, Loss: 1.4756, Val Loss: 0.0109, Accuracy: 51.39%
# Epoch 7, Loss: 1.1572, Val Loss: 0.0108, Accuracy: 52.06%
# Epoch 8, Loss: 1.3610, Val Loss: 0.0108, Accuracy: 51.65%
# Epoch 9, Loss: 1.2513, Val Loss: 0.0108, Accuracy: 51.96%
# Epoch 10, Loss: 1.0685, Val Loss: 0.0109, Accuracy: 52.68%
# Epoch 11, Loss: 1.1445, Val Loss: 0.0108, Accuracy: 53.07%
# Epoch 12, Loss: 1.2400, Val Loss: 0.0108, Accuracy: 52.73%
# Epoch 13, Loss: 0.9693, Val Loss: 0.0111, Accuracy: 52.31%
# Epoch 14, Loss: 1.2860, Val Loss: 0.0109, Accuracy: 53.00%
# Epoch 15, Loss: 1.1764, Val Loss: 0.0112, Accuracy: 52.39%
# Epoch 16, Loss: 0.8532, Val Loss: 0.0112, Accuracy: 52.75%
# Epoch 17, Loss: 0.8936, Val Loss: 0.0112, Accuracy: 53.17%
# Epoch 18, Loss: 1.1298, Val Loss: 0.0117, Accuracy: 52.99%
# Epoch 19, Loss: 0.7990, Val Loss: 0.0116, Accuracy: 52.48%
# Epoch 20, Loss: 0.9451, Val Loss: 0.0119, Accuracy: 52.38%
# Epoch 21, Loss: 0.9879, Val Loss: 0.0119, Accuracy: 52.63%
# Epoch 22, Loss: 0.8870, Val Loss: 0.0120, Accuracy: 51.54%
# Epoch 23, Loss: 0.7468, Val Loss: 0.0122, Accuracy: 52.67%
# Epoch 24, Loss: 0.7715, Val Loss: 0.0124, Accuracy: 52.71%
# Epoch 25, Loss: 0.8714, Val Loss: 0.0127, Accuracy: 51.48%
# Epoch 26, Loss: 0.8011, Val Loss: 0.0123, Accuracy: 52.40%
# Epoch 27, Loss: 0.9777, Val Loss: 0.0127, Accuracy: 51.73%
# Epoch 28, Loss: 0.9566, Val Loss: 0.0129, Accuracy: 52.23%
# Epoch 29, Loss: 0.7824, Val Loss: 0.0133, Accuracy: 51.56%
# Epoch 30, Loss: 0.7034, Val Loss: 0.0129, Accuracy: 51.74%
# Epoch 31, Loss: 0.7602, Val Loss: 0.0135, Accuracy: 52.13%
# Epoch 32, Loss: 0.7149, Val Loss: 0.0138, Accuracy: 51.04%
# Epoch 33, Loss: 0.8887, Val Loss: 0.0138, Accuracy: 51.67%
# Epoch 34, Loss: 0.8682, Val Loss: 0.0142, Accuracy: 52.07%
# Epoch 35, Loss: 0.8306, Val Loss: 0.0142, Accuracy: 51.54%
# Epoch 36, Loss: 0.6039, Val Loss: 0.0142, Accuracy: 51.69%
# Epoch 37, Loss: 0.6782, Val Loss: 0.0145, Accuracy: 51.63%
# Epoch 38, Loss: 0.6635, Val Loss: 0.0148, Accuracy: 51.12%
# Epoch 39, Loss: 0.5370, Val Loss: 0.0150, Accuracy: 52.36%
# Epoch 40, Loss: 0.7460, Val Loss: 0.0153, Accuracy: 51.49%
# Epoch 41, Loss: 0.6824, Val Loss: 0.0155, Accuracy: 51.44%
# Epoch 42, Loss: 0.4791, Val Loss: 0.0160, Accuracy: 51.46%
# Epoch 43, Loss: 0.5347, Val Loss: 0.0152, Accuracy: 50.62%
# Epoch 44, Loss: 0.7114, Val Loss: 0.0155, Accuracy: 51.16%
# Epoch 45, Loss: 0.8083, Val Loss: 0.0163, Accuracy: 50.68%
# Epoch 46, Loss: 0.5892, Val Loss: 0.0162, Accuracy: 51.95%
# Epoch 47, Loss: 0.7306, Val Loss: 0.0162, Accuracy: 50.74%
# Epoch 48, Loss: 0.5930, Val Loss: 0.0167, Accuracy: 51.15%
# Epoch 49, Loss: 0.4784, Val Loss: 0.0173, Accuracy: 50.78%
# Epoch 50, Loss: 0.5997, Val Loss: 0.0167, Accuracy: 51.47%
# Epoch 51, Loss: 0.6363, Val Loss: 0.0168, Accuracy: 50.66%
# Epoch 52, Loss: 0.6804, Val Loss: 0.0173, Accuracy: 50.69%
# Epoch 53, Loss: 0.6992, Val Loss: 0.0176, Accuracy: 51.12%
# Epoch 54, Loss: 0.4613, Val Loss: 0.0176, Accuracy: 50.95%
# Epoch 55, Loss: 0.7357, Val Loss: 0.0174, Accuracy: 50.53%
# Epoch 56, Loss: 0.7114, Val Loss: 0.0177, Accuracy: 50.86%
# Epoch 57, Loss: 0.5668, Val Loss: 0.0178, Accuracy: 50.34%
# Epoch 58, Loss: 0.7716, Val Loss: 0.0185, Accuracy: 50.70%
# Epoch 59, Loss: 0.6037, Val Loss: 0.0188, Accuracy: 50.69%
# Epoch 60, Loss: 0.6969, Val Loss: 0.0182, Accuracy: 50.88%
# Epoch 61, Loss: 0.5334, Val Loss: 0.0189, Accuracy: 50.32%
# Epoch 62, Loss: 0.8011, Val Loss: 0.0185, Accuracy: 50.74%
# Epoch 63, Loss: 0.5051, Val Loss: 0.0189, Accuracy: 50.92%
# Epoch 64, Loss: 0.4847, Val Loss: 0.0190, Accuracy: 50.62%
# Epoch 65, Loss: 0.8224, Val Loss: 0.0191, Accuracy: 50.18%
# Epoch 66, Loss: 0.5977, Val Loss: 0.0192, Accuracy: 50.39%
# Epoch 67, Loss: 0.3728, Val Loss: 0.0205, Accuracy: 50.39%
# Epoch 68, Loss: 0.6137, Val Loss: 0.0199, Accuracy: 50.38%
# Epoch 69, Loss: 0.4381, Val Loss: 0.0196, Accuracy: 50.14%
# Epoch 70, Loss: 0.5435, Val Loss: 0.0206, Accuracy: 50.31%
# Epoch 71, Loss: 0.5931, Val Loss: 0.0195, Accuracy: 50.01%
# Epoch 72, Loss: 0.5622, Val Loss: 0.0206, Accuracy: 50.60%
# Epoch 73, Loss: 0.3139, Val Loss: 0.0214, Accuracy: 50.31%
# Epoch 74, Loss: 0.4556, Val Loss: 0.0212, Accuracy: 50.54%
# Epoch 75, Loss: 0.5074, Val Loss: 0.0198, Accuracy: 50.29%
# Epoch 76, Loss: 0.4984, Val Loss: 0.0214, Accuracy: 50.32%
# Epoch 77, Loss: 0.5317, Val Loss: 0.0216, Accuracy: 50.58%
# Epoch 78, Loss: 0.4086, Val Loss: 0.0210, Accuracy: 50.53%
# Epoch 79, Loss: 0.5221, Val Loss: 0.0214, Accuracy: 50.74%
# Epoch 80, Loss: 0.4549, Val Loss: 0.0211, Accuracy: 50.40%
# Epoch 81, Loss: 0.5344, Val Loss: 0.0219, Accuracy: 49.93%
# Epoch 82, Loss: 0.3965, Val Loss: 0.0222, Accuracy: 50.58%
# Epoch 83, Loss: 0.5866, Val Loss: 0.0214, Accuracy: 50.10%
# Epoch 84, Loss: 0.3723, Val Loss: 0.0221, Accuracy: 49.61%
# Epoch 85, Loss: 0.5554, Val Loss: 0.0230, Accuracy: 49.97%
# Epoch 86, Loss: 0.3608, Val Loss: 0.0218, Accuracy: 50.57%
# Epoch 87, Loss: 0.4548, Val Loss: 0.0223, Accuracy: 50.57%
# Epoch 88, Loss: 0.3051, Val Loss: 0.0223, Accuracy: 50.39%
# Epoch 89, Loss: 0.4934, Val Loss: 0.0232, Accuracy: 50.17%
# Epoch 90, Loss: 0.5736, Val Loss: 0.0228, Accuracy: 50.31%
# Epoch 91, Loss: 0.3035, Val Loss: 0.0226, Accuracy: 50.05%
# Epoch 92, Loss: 0.5101, Val Loss: 0.0238, Accuracy: 50.36%
# Epoch 93, Loss: 0.6908, Val Loss: 0.0217, Accuracy: 49.94%
# Epoch 94, Loss: 0.3322, Val Loss: 0.0245, Accuracy: 50.18%
# Epoch 95, Loss: 0.2531, Val Loss: 0.0240, Accuracy: 49.77%
# Epoch 96, Loss: 0.4848, Val Loss: 0.0246, Accuracy: 49.85%
# Epoch 97, Loss: 0.4354, Val Loss: 0.0244, Accuracy: 50.37%
# Epoch 98, Loss: 0.4546, Val Loss: 0.0240, Accuracy: 49.75%
# Epoch 99, Loss: 0.7293, Val Loss: 0.0249, Accuracy: 50.43%
